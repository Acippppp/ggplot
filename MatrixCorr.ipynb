# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
# !pip install seaborn
import seaborn as sns

# %%
#Load Data
Rempah =pd.read_csv('C:/Users/Hp/Documents/Rempah.csv')
Rempah
# Out:
#            Date    Aji  Brahims   Kawan
# 0    02/01/2015   5.50    1.370    1.05
# 1    05/01/2015   5.56    1.350    1.05
# 2    06/01/2015   5.51    1.350  1.0575
# 3    07/01/2015   5.50    1.330  1.0575
# 4    08/01/2015   5.50    1.330  1.0875
# ..          ...    ...      ...     ...
# 995  04/01/2019  18.60    0.195    1.91
# 996  07/01/2019  18.60    0.200    1.92
# 997  08/01/2019  18.40    0.200    1.92
# 998  09/01/2019  18.32    0.210    1.93
# 999  10/01/2019  18.32    0.210    1.92
#
# [1000 rows x 4 columns]

# %%
type(Rempah.loc[0,'Kawan'])
# Out:
# str

# %%
Rempah['Kawan']=Rempah['Kawan'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-f6710839b05e> in <module>
# ----> 1 Rempah['Kawan']=Rempah['Kawan'].astype(float)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
# ...

# %%
x=Rempah[Rempah['Kawan'].str.contains('N')]
x
# Out:
#            Date    Aji  Brahims Kawan
# 664  04/09/2017  21.24    0.525    \N
# 780  16/02/2018  20.00    0.340    \N

# %%
Rempah=Rempah.drop(labels=[664,780], axis=0)
Rempah
# Out:
#            Date    Aji  Brahims   Kawan
# 0    02/01/2015   5.50    1.370    1.05
# 1    05/01/2015   5.56    1.350    1.05
# 2    06/01/2015   5.51    1.350  1.0575
# 3    07/01/2015   5.50    1.330  1.0575
# 4    08/01/2015   5.50    1.330  1.0875
# ..          ...    ...      ...     ...
# 995  04/01/2019  18.60    0.195    1.91
# 996  07/01/2019  18.60    0.200    1.92
# 997  08/01/2019  18.40    0.200    1.92
# 998  09/01/2019  18.32    0.210    1.93
# 999  10/01/2019  18.32    0.210    1.92
#
# [998 rows x 4 columns]

# %%
Rempah['Kawan']=Rempah['Kawan'].astype(float)

# %%
#Create matrix for heatmap
matrix =Rempah.corr()
matrix
# Out:
#               Aji   Brahims     Kawan
# Aji      1.000000 -0.793885  0.574533
# Brahims -0.793885  1.000000 -0.205532
# Kawan    0.574533 -0.205532  1.000000

# %%
#Plot Heatmap
plt.figure(figsize=(10,10))
sns.heatmap(matrix,annot=True)
plt.title('Heatmap Rempah ')
# Out:
# Text(0.5, 1.0, 'Heatmap Rempah ')

# %%
#Matrix Scatterplot
sns.pairplot(Rempah)

# %%
plt.figure(figsize=(10,10))
plt.plot(Rempah.Aji)
plt.plot(Rempah.Brahims)
plt.plot(Rempah.Kawan)
plt.legend()
# Out:
# No handles with labels found to put in legend.
